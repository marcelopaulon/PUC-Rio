# %%
### WARNING: This notebook only has to be run once, to populate Delivery Rate scalars in the database.

import random
import pandas as pd

import psycopg2 as pg
import sqlalchemy


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams.update({'font.size': 24})
plt.rcParams.update({'font.weight': 'bold'})

def parse_if_number(s):
    try: return float(s)
    except: return True if s=="true" else False if s=="false" else s if s else None

def parse_ndarray(s):
    return np.fromstring(s, sep=' ') if s else None

# %%
from sqlalchemy import create_engine

POSTGRES_ADDRESS = 'localhost'
POSTGRES_PORT = '5432'
POSTGRES_USERNAME = 'postgres'
POSTGRES_PASSWORD = 'postgres'
POSTGRES_DBNAME = 'mam'

postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'.format(username=POSTGRES_USERNAME, password=POSTGRES_PASSWORD, ipaddress=POSTGRES_ADDRESS, port=POSTGRES_PORT, dbname=POSTGRES_DBNAME))

cnx = create_engine(postgres_str)

# Select first 5 rows
pd.read_sql_query('''SELECT * FROM scalars LIMIT 5;''', cnx)
# Out:
#    node_amount  area_sq_m  lpn_fn_ratio relay_type  delta_ms  speed_ms  \
# 0           50       1000             8   MAMRELAY         2        14
# 1           50        800             8   MAMRELAY      5000         2
# 2           50        800             8   MAMRELAY      5000         2
# 3           50        800             8   MAMRELAY      5000         2
# 4           50       1000             8   MAMRELAY         2        14
#
#    series  rep                                             module  \
# 0       5    0  MAM_n50_a1000m2_lpnFn8_5.host_fn_rly_6.wlan[0]...
# 1       9    0       MAM_n50_a800m2_lpnFn8_9.host_fn_rly_4.app[0]
# 2       9    0       MAM_n50_a800m2_lpnFn8_9.host_fn_rly_4.app[0]
# 3       9    0       MAM_n50_a800m2_lpnFn8_9.host_fn_rly_4.app[0]
# 4       5    0  MAM_n50_a1000m2_lpnFn8_5.host_fn_rly_6.wlan[0]...
#
#                                       name    type  value  \
# 0  packetDropQueueOverlow:sum(packetBytes)  scalar    0.0
# 1                             packets sent  scalar    0.0
# 2                         packets received  scalar    0.0
# 3                        data packets sent  scalar  155.0
# 4        packetDropRetryLimitReached:count  scalar   71.0
#
#                                             full_row  created_at
# 0  MAM_n50_a1000m2_lpnFn8_5-MAMRELAY-5-20201226-1...  2020-12-28
# 1  MAM_n50_a800m2_lpnFn8_9-MAMRELAY-27-20201225-0...  2020-12-28
# 2  MAM_n50_a800m2_lpnFn8_9-MAMRELAY-27-20201225-0...  2020-12-28
# 3  MAM_n50_a800m2_lpnFn8_9-MAMRELAY-27-20201225-0...  2020-12-28
# 4  MAM_n50_a1000m2_lpnFn8_5-MAMRELAY-5-20201226-1...  2020-12-28

# %%
primaryKeyColumns = ['node_amount', 'area_sq_m', 'lpn_fn_ratio', 'relay_type', 'delta_ms', 'speed_ms', 'series', 'rep']
primaryKeyColumnsCSV = ','.join(primaryKeyColumns)
tPrimaryKeyColumnsCSV = ','.join(['t.' + x for x in primaryKeyColumns])

allRuns = pd.read_sql_query('''
WITH RECURSIVE
     t AS (
  select ''' + primaryKeyColumnsCSV + ''' from
    (select ''' + primaryKeyColumnsCSV + ''' from scalars
    order by ''' + primaryKeyColumnsCSV + ''' limit 1) asdf
  union all
  select '''
     +
     ','.join(['(select ' + x + ' from scalars where (' + primaryKeyColumnsCSV + ') > (' + tPrimaryKeyColumnsCSV + ') order by ' + primaryKeyColumnsCSV + ' limit 1)' for x in primaryKeyColumns])
     +                       
  '''from t where t.''' + primaryKeyColumns[0] + ''' is not null)
select * from t where t.''' + primaryKeyColumns[0] + ''' is not null;
''', cnx)
allRuns
# Out:
#        node_amount  area_sq_m  lpn_fn_ratio relay_type  delta_ms  speed_ms  \
# 0               50        400             4    BMRELAY         0         2
# 1               50        400             4    BMRELAY         0         2
# 2               50        400             4    BMRELAY         0         2
# 3               50        400             4    BMRELAY         0         2
# 4               50        400             4    BMRELAY         0         2
# ...            ...        ...           ...        ...       ...       ...
# 11067          200       1000            12   MAMRELAY     20000        14
# 11068          200       1000            12   MAMRELAY     20000        14
# 11069          200       1000            12   MAMRELAY     20000        14
# 11070          200       1000            12   MAMRELAY     20000        14
# 11071          200       1000            12   MAMRELAY     20000        14
#
#        series  rep
# 0           0    0
# 1           1    0
# 2           2    0
# 3           3    0
# 4           4    0
# ...       ...  ...
# 11067       5    0
# 11068       6    0
# 11069       7    0
# 11070       8    0
# 11071       9    0
#
# [11072 rows x 8 columns]

# %%
moduleName = 'MAM-Large-Generate-Delivery-Rate-Scalars'
simCount = len(allRuns)
progress = 0

def saveDeliveryRate(data, deliveryRate):
    formattedValues = ''
    for x in primaryKeyColumns:
        formattedField = data[x]
        if (x in ['relay_type']):
            formattedField = '\'' + formattedField + '\''
        formattedValues = formattedValues + str(formattedField) + ','
    formattedValues = formattedValues + '\'' + moduleName + '\','
    
    formattedValues = formattedValues + '\'delivery rate\','
    formattedValues = formattedValues + '\'' + str(deliveryRate) + '\''
    
    query = 'insert into scalars (' + primaryKeyColumnsCSV + ',module,name,value,created_at) ' + '''
        values (''' + formattedValues + ', now()) on conflict do nothing;'
    #print(query)
    cnx.execute(query)

while progress < simCount:
    temp = allRuns.iloc[progress]

    testa = pd.read_sql_query('select name, value from scalars where node_amount=' + str(temp['node_amount']) + 
    ' and area_sq_m=' + str(temp['area_sq_m']) + ' and lpn_fn_ratio='+ str(temp['lpn_fn_ratio']) +
    ' and relay_type=\'' + str(temp['relay_type']) + '\' and delta_ms='+ str(temp['delta_ms']) + 
    ' and speed_ms=' + str(temp['speed_ms']) + ' and series='+ str(temp['series']) + ' and rep=' + str(temp['rep']) + 
    ''' and (name like 'generated packet uuids%' or name like 'received packet uuids%') ''', cnx)
    generatedDf = testa[testa['name'].str.startswith('generated packet uuids')]
    receivedDf = testa[testa['name'].str.startswith('received packet uuids')]

    generatedArr = generatedDf['value']
    receivedArr = receivedDf['value']

    generated = set()
    received = set()

    for x in generatedArr:
        generated.update(x.split(','))

    for x in receivedArr:
        received.update(x.split(','))

    deliveryRate = len(received)/len(generated)*100
    saveDeliveryRate(temp, deliveryRate)
    progress = progress + 1
    if progress % 50 == 0 or (simCount - progress) < 10:
        print('Progress=' + "{:.3f}".format((progress/simCount)*100.0) + '%')
# Out:
# Progress=0.452%
# Progress=0.903%
# Progress=1.355%
# Progress=1.806%
# Progress=2.258%
# Progress=2.710%
# Progress=3.161%
# Progress=3.613%
# Progress=4.064%
# Progress=4.516%
# Progress=4.967%
# Progress=5.419%
# Progress=5.871%
# Progress=6.322%
# Progress=6.774%
# Progress=7.225%
# Progress=7.677%
# Progress=8.129%
# Progress=8.580%
# Progress=9.032%
# Progress=9.483%
# Progress=9.935%
# Progress=10.387%
# Progress=10.838%
# Progress=11.290%
# Progress=11.741%
# Progress=12.193%
# Progress=12.645%
# Progress=13.096%
# Progress=13.548%
# Progress=13.999%
# Progress=14.451%
# Progress=14.902%
# Progress=15.354%
# Progress=15.806%
# Progress=16.257%
# Progress=16.709%
# Progress=17.160%
# Progress=17.612%
# Progress=18.064%
# Progress=18.515%
# Progress=18.967%
# Progress=19.418%
# Progress=19.870%
# Progress=20.322%
# Progress=20.773%
# Progress=21.225%
# Progress=21.676%
# Progress=22.128%
# Progress=22.579%
# Progress=23.031%
# Progress=23.483%
# Progress=23.934%
# Progress=24.386%
# Progress=24.837%
# Progress=25.289%
# Progress=25.741%
# Progress=26.192%
# Progress=26.644%
# Progress=27.095%
# Progress=27.547%
# Progress=27.999%
# Progress=28.450%
# Progress=28.902%
# Progress=29.353%
# Progress=29.805%
# Progress=30.257%
# Progress=30.708%
# Progress=31.160%
# Progress=31.611%
# Progress=32.063%
# Progress=32.514%
# Progress=32.966%
# Progress=33.418%
# Progress=33.869%
# Progress=34.321%
# Progress=34.772%
# Progress=35.224%
# Progress=35.676%
# Progress=36.127%
# Progress=36.579%
# Progress=37.030%
# Progress=37.482%
# Progress=37.934%
# Progress=38.385%
# Progress=38.837%
# Progress=39.288%
# Progress=39.740%
# Progress=40.191%
# Progress=40.643%
# Progress=41.095%
# Progress=41.546%
# Progress=41.998%
# Progress=42.449%
# Progress=42.901%
# Progress=43.353%
# Progress=43.804%
# Progress=44.256%
# Progress=44.707%
# Progress=45.159%
# Progress=45.611%
# Progress=46.062%
# Progress=46.514%
# Progress=46.965%
# Progress=47.417%
# Progress=47.868%
# Progress=48.320%
# Progress=48.772%
# Progress=49.223%
# Progress=49.675%
# Progress=50.126%
# Progress=50.578%
# Progress=51.030%
# Progress=51.481%
# Progress=51.933%
# Progress=52.384%
# Progress=52.836%
# Progress=53.288%
# Progress=53.739%
# Progress=54.191%
# Progress=54.642%
# Progress=55.094%
# Progress=55.546%
# Progress=55.997%
# Progress=56.449%
# Progress=56.900%
# Progress=57.352%
# Progress=57.803%
# Progress=58.255%
# Progress=58.707%
# Progress=59.158%
# Progress=59.610%
# Progress=60.061%
# Progress=60.513%
# Progress=60.965%
# Progress=61.416%
# Progress=61.868%
# Progress=62.319%
# Progress=62.771%
# Progress=63.223%
# Progress=63.674%
# Progress=64.126%
# Progress=64.577%
# Progress=65.029%
# Progress=65.480%
# Progress=65.932%
# Progress=66.384%
# Progress=66.835%
# Progress=67.287%
# Progress=67.738%
# Progress=68.190%
# Progress=68.642%
# Progress=69.093%
# Progress=69.545%
# Progress=69.996%
# Progress=70.448%
# Progress=70.900%
# Progress=71.351%
# Progress=71.803%
# Progress=72.254%
# Progress=72.706%
# Progress=73.158%
# Progress=73.609%
# Progress=74.061%
# Progress=74.512%
# Progress=74.964%
# Progress=75.415%
# Progress=75.867%
# Progress=76.319%
# Progress=76.770%
# Progress=77.222%
# Progress=77.673%
# Progress=78.125%
# Progress=78.577%
# Progress=79.028%
# Progress=79.480%
# Progress=79.931%
# Progress=80.383%
# Progress=80.835%
# Progress=81.286%
# Progress=81.738%
# Progress=82.189%
# Progress=82.641%
# Progress=83.092%
# Progress=83.544%
# Progress=83.996%
# Progress=84.447%
# Progress=84.899%
# Progress=85.350%
# Progress=85.802%
# Progress=86.254%
# Progress=86.705%
# Progress=87.157%
# Progress=87.608%
# Progress=88.060%
# Progress=88.512%
# Progress=88.963%
# Progress=89.415%
# Progress=89.866%
# Progress=90.318%
# Progress=90.770%
# Progress=91.221%
# Progress=91.673%
# Progress=92.124%
# Progress=92.576%
# Progress=93.027%
# Progress=93.479%
# Progress=93.931%
# Progress=94.382%
# Progress=94.834%
# Progress=95.285%
# Progress=95.737%
# Progress=96.189%
# Progress=96.640%
# Progress=97.092%
# Progress=97.543%
# Progress=97.995%
# Progress=98.447%
# Progress=98.898%
# Progress=99.350%
# Progress=99.801%
# Progress=99.919%
# Progress=99.928%
# Progress=99.937%
# Progress=99.946%
# Progress=99.955%
# Progress=99.964%
# Progress=99.973%
# Progress=99.982%
# Progress=99.991%
# Progress=100.000%

# %%
lastRun = allRuns.iloc[len(allRuns)-1]
lastRunDeliveryRate = pd.read_sql_query('select * from scalars where node_amount=' + str(lastRun['node_amount']) + 
' and area_sq_m=' + str(lastRun['area_sq_m']) + ' and lpn_fn_ratio='+ str(lastRun['lpn_fn_ratio']) +
' and relay_type=\'' + str(lastRun['relay_type']) + '\' and delta_ms='+ str(lastRun['delta_ms']) + 
' and speed_ms=' + str(lastRun['speed_ms']) + ' and series='+ str(lastRun['series']) + ' and rep=' + str(lastRun['rep']) + 
''' and (name = 'delivery rate') ''', cnx)

if lastRunDeliveryRate.empty:
    raise Exception('Non-existent delivery rate. Make sure to have run MAM-Large-Generate-Delivery-Rate-Scalars notebook')

lastRunDeliveryRate
# Out:
#    node_amount  area_sq_m  lpn_fn_ratio relay_type  delta_ms  speed_ms  \
# 0          200       1000            12   MAMRELAY     20000        14
#
#    series  rep                                    module           name  type  \
# 0       9    0  MAM-Large-Generate-Delivery-Rate-Scalars  delivery rate  None
#
#                value full_row  created_at
# 0  9.113396693138915     None  2021-02-04
